# %% [markdown]
# # HAMOYE Internship Stage A

# %% [markdown]
# ## Questions on the dataset

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Reading in the Data

# %%
url ='https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
df = pd.read_csv(url,error_bad_lines=False, encoding='latin-1')
# Out:
# <ipython-input-28-93fc2021e48c>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(url,error_bad_lines=False, encoding='latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# Which year had the least correlation with Element Code?

# %%
df.corr()
# Out:
# <ipython-input-30-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %% [markdown]
# From the correlation table, the year with the least correlation is year *2016*

# %%
df['Element'].unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %% [markdown]
# Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
df[df['Element']=='Processing'].groupby('Element')['Y2017'].sum()
# Out:
# Element
# Processing    292836.0
# Name: Y2017, dtype: float64

# %% [markdown]
# Total sum on processing in 2017 is 2928836

# %%
df[df['Area']=='Madagascar'].groupby('Element')['Y2015'].sum()
# Out:
# Element
# Domestic supply quantity                  31214.98
# Export Quantity                             494.75
# Fat supply quantity (g/capita/day)           91.85
# Feed                                       2070.22
# Food                                      21120.65
# Food supply (kcal/capita/day)              7685.00
# Food supply quantity (kg/capita/yr)         871.59
# Import Quantity                            1721.80
# Losses                                     2176.00
# Other uses (non-food)                      3957.12
# Processing                                 1803.00
# Production                                29482.89
# Protein supply quantity (g/capita/day)      173.05
# Residuals                                  -616.00
# Seed                                        699.00
# Stock Variation                            -505.00
# Total Population - Both sexes             24234.00
# Name: Y2015, dtype: float64

# %% [markdown]
# The total protein supply quantity in Madagascar in 2015 is 173.05 units

# %% [markdown]
# Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
df.groupby('Element')[['Y2014','Y2015','Y2016','Y2017','Y2018']].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %% [markdown]
# *From the table above, year 2014 has the highest stock variation*

# %% [markdown]
# What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
print(df['Y2017'].mean())
print(df['Y2017'].std())
# Out:
# 140.9177648602722
# 1671.8623590567995

# %% [markdown]
# The mean and standard deviation is 140.92 and 1671.86 to 2 decimal places

# %% [markdown]
# Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
df.groupby('Area')['Y2017'].sum().sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %% [markdown]
# From the result above, the country with the lowest sum is Guinea Bissau

# %% [markdown]
# What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
print(df.isnull().sum())
pd.DataFrame((df.isnull().sum())/len(df)*100,columns=['percentage of missing values'])
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
#               percentage of missing values
# Area Code                         0.000000
# Area                              0.000000
# Item Code                         0.000000
# Item                              0.000000
# Element Code                      0.000000
# Element                           0.000000
# Unit                              0.000000
# Y2014                             2.607354
# Y2015                             2.540078
# Y2016                             2.518747
# Y2017                             2.471162
# Y2018                             2.356300

# %% [markdown]
# Number and Percentage of missing values for year 2014 is 1589 and 2.607%

# %% [markdown]
# Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
df.groupby('Area')['Y2017'].sum().sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %% [markdown]
# *Nigeria* has the highest sum in year *2017*

# %% [markdown]
# ## Other Questions

# %% [markdown]
# What would be the output for?
#
# S = [['him', 'sell'], [90, 28, 43]]
#
# S[0][1][1]

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# A pandas Dataframe with dimensions (100,3) has how many features and observations?
#
# Ans: 3 features, 100 observations

# %% [markdown]
# How would you check for the number of rows and columns in a pandas DataFrame named df?
#
# Ans: df.shape

# %% [markdown]
# Which of the following is a python inbuilt module?
#
# Ans:
# Matplotlib
#
# Pandas
#
# Seaborn
#
# Math

# %% [markdown]
# If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# How do you create a pandas DataFrame using this list, to look like the table below?
# Ans: pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
##Given the following python code, what would the output of the code give?
#Ans: Type error
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-589f225a5d01> in <cell line: 5>()
#       3 my_tuppy = (1,2,5,8)
#       4
# ----> 5 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# What is the total number of unique countries in the dataset?

# %%
df['Area'].nunique()
# Out:
# 49
